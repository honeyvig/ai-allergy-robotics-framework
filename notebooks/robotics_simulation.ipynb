# %% [markdown]
# # Robotics Simulation Demo

# %%
from src.orchestrator import run_demo
print(run_demo({'id':'p1','maternal_allergy':1,'paternal_allergy':0,'early_eczema':1,'urban_residence':1,'sibling_allergy':0}))
